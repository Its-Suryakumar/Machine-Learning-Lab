# %%
# K Nearest Neighbours
## Dataset - Iris.csv
### Suryakumar P 21MIS1146

# %%
import sys
print(sys.version)
# Out:
# 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pt

# %%
name = ["B","G","R","y"]

# %%
dataset = pd.read_csv("iris.csv")

# %%
dataset.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,4].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      0.92      0.96        12
#   Versicolor       0.60      1.00      0.75         6
#    Virginica       1.00      0.75      0.86        12
#
#     accuracy                           0.87        30
#    macro avg       0.87      0.89      0.85        30
# weighted avg       0.92      0.87      0.88        30
#
# [[11  1  0]
#  [ 0  6  0]
#  [ 0  3  9]]

# %%
import seaborn as sn
array = [[10,0,0],[0,7,0],[0,2,11]]
df_cm = pd.DataFrame(array, range(3), range(3))
pt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
pt.show()

# %%
K = [] 
training = [] 
test = [] 
scores = {}

# %%
for k in range(2, 21): 
    clf = KNeighborsClassifier(n_neighbors = k) 
    clf.fit(X_train, y_train) 
  
    training_score = clf.score(X_train, y_train) 
    test_score = clf.score(X_test, y_test) 
    K.append(k) 
  
    training.append(training_score) 
    test.append(test_score) 
    scores[k] = [training_score, test_score]

# %%
for keys, values in scores.items(): 
	print(keys, ':', values)
# Out:
# 2 : [0.9666666666666667, 1.0]
# 3 : [0.9416666666666667, 1.0]
# 4 : [0.95, 0.9666666666666667]
# 5 : [0.9416666666666667, 1.0]
# 6 : [0.95, 0.9666666666666667]
# 7 : [0.9416666666666667, 0.9666666666666667]
# 8 : [0.95, 0.9666666666666667]
# 9 : [0.9416666666666667, 0.9666666666666667]
# 10 : [0.9416666666666667, 0.9666666666666667]
# 11 : [0.95, 0.9666666666666667]
# 12 : [0.95, 0.9666666666666667]
# 13 : [0.95, 0.9666666666666667]
# 14 : [0.95, 1.0]
# 15 : [0.95, 1.0]
# 16 : [0.95, 1.0]
# 17 : [0.9333333333333333, 0.9666666666666667]
# 18 : [0.95, 0.9666666666666667]
# 19 : [0.9333333333333333, 0.9666666666666667]
# 20 : [0.9333333333333333, 0.9666666666666667]
